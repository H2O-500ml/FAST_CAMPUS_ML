# %%
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
# %matplotlib inline

# %% [markdown]
# ### See available TTFs

# %%
matplotlib.font_manager.fontManager.ttflist
# Out:
# [<Font 'STIXNonUnicode' (STIXNonUni.ttf) normal normal regular normal>,
#  <Font 'cmr10' (cmr10.ttf) normal normal 400 normal>,
#  <Font 'STIXSizeThreeSym' (STIXSizThreeSymReg.ttf) normal normal regular normal>,
#  <Font 'DejaVu Sans' (DejaVuSans-Oblique.ttf) oblique normal 400 normal>,
#  <Font 'DejaVu Serif' (DejaVuSerif-BoldItalic.ttf) italic normal bold normal>,
#  <Font 'DejaVu Serif' (DejaVuSerif.ttf) normal normal 400 normal>,
#  <Font 'STIXSizeThreeSym' (STIXSizThreeSymBol.ttf) normal normal bold normal>,
#  <Font 'STIXSizeFourSym' (STIXSizFourSymBol.ttf) normal normal bold normal>,
#  <Font 'STIXSizeFourSym' (STIXSizFourSymReg.ttf) normal normal regular normal>,
#  <Font 'DejaVu Serif' (DejaVuSerif-Italic.ttf) italic normal 400 normal>,
#  <Font 'DejaVu Sans' (DejaVuSans.ttf) normal normal 400 normal>,
#  <Font 'DejaVu Serif Display' (DejaVuSerifDisplay.ttf) normal normal 400 normal>,
#  <Font 'cmmi10' (cmmi10.ttf) normal normal 400 normal>,
#  <Font 'DejaVu Sans Mono' (DejaVuSansMono-Bold.ttf) normal normal bold normal>,
#  <Font 'cmex10' (cmex10.ttf) normal normal 400 normal>,
#  <Font 'STIXNonUnicode' (STIXNonUniIta.ttf) italic normal 400 normal>,
#  <Font 'STIXGeneral' (STIXGeneralBol.ttf) normal normal bold normal>,
#  <Font 'DejaVu Sans' (DejaVuSans-Bold.ttf) normal normal bold normal>,
#  <Font 'DejaVu Sans Mono' (DejaVuSansMono.ttf) normal normal 400 normal>,
#  <Font 'STIXSizeOneSym' (STIXSizOneSymBol.ttf) normal normal bold normal>,
#  <Font 'STIXSizeOneSym' (STIXSizOneSymReg.ttf) normal normal regular normal>,
#  <Font 'cmss10' (cmss10.ttf) normal normal 400 normal>,
#  <Font 'cmsy10' (cmsy10.ttf) normal normal 400 normal>,
#  <Font 'cmb10' (cmb10.ttf) normal normal 400 normal>,
#  <Font 'STIXGeneral' (STIXGeneralBolIta.ttf) italic normal bold normal>,
#  <Font 'STIXGeneral' (STIXGeneral.ttf) normal normal regular normal>,
#  <Font 'STIXSizeTwoSym' (STIXSizTwoSymReg.ttf) normal normal regular normal>,
#  <Font 'STIXNonUnicode' (STIXNonUniBol.ttf) normal normal bold normal>,
#  <Font 'cmtt10' (cmtt10.ttf) normal normal 400 normal>,
#  <Font 'DejaVu Sans' (DejaVuSans-BoldOblique.ttf) oblique normal bold normal>,
#  <Font 'STIXNonUnicode' (STIXNonUniBolIta.ttf) italic normal bold normal>,
#  <Font 'STIXGeneral' (STIXGeneralItalic.ttf) italic normal 400 normal>,
#  <Font 'DejaVu Serif' (DejaVuSerif-Bold.ttf) normal normal bold normal>,
#  <Font 'DejaVu Sans Mono' (DejaVuSansMono-Oblique.ttf) oblique normal 400 normal>,
#  <Font 'DejaVu Sans Mono' (DejaVuSansMono-BoldOblique.ttf) oblique normal bold normal>,
#  <Font 'STIXSizeTwoSym' (STIXSizTwoSymBol.ttf) normal normal bold normal>,
#  <Font 'STIXSizeFiveSym' (STIXSizFiveSymReg.ttf) normal normal regular normal>,
#  <Font 'DejaVu Sans Display' (DejaVuSansDisplay.ttf) normal normal 400 normal>,
#  <Font 'SF Pro Text' (SF-Pro-Text-MediumItalic.otf) normal normal 400 normal>,
#  <Font 'Narkisim' (nrkis.ttf) normal normal 400 normal>,
#  <Font 'Microsoft Tai Le' (taileb.ttf) normal normal bold normal>,
#  <Font 'Tunga' (tungab.ttf) normal normal bold normal>,
#  <Font 'Segoe UI' (seguisb.ttf) normal normal 400 normal>,
#  <Font 'Rosewood Std' (RosewoodStd-Regular.otf) normal normal 400 normal>,
#  <Font 'Haan YGodic 250' (HANYGO250.ttf) normal normal 400 normal>,
#  <Font 'Myriad Pro' (MyriadPro-Bold.otf) normal normal bold normal>,
#  <Font 'MurrayHill Bd BT' (ENMUHB.TTF) normal normal 400 normal>,
#  <Font 'Adobe Arabic' (AdobeArabic-BoldItalic.otf) italic normal bold normal>,
#  <Font 'Bodoni MT' (BOD_PSTC.TTF) normal normal 400 normal>,
#  <Font 'High Tower Text' (HTOWERT.TTF) normal normal 400 normal>,
#  <Font 'Minion Pro' (MinionPro-Bold.otf) normal normal bold normal>,
#  <Font 'HYPMokGak-Bold' (H2MKPB.TTF) normal normal 400 normal>,
#  <Font 'Haan YGodic 240' (HANYGO240.ttf) normal normal 400 normal>,
#  <Font 'Calisto MT' (CALISTI.TTF) italic normal 400 normal>,
#  <Font 'Tw Cen MT' (TCBI____.TTF) italic normal bold normal>,
#  <Font 'Minion Pro' (MinionPro-It.otf) italic normal 400 normal>,
#  <Font 'IrisUPC' (upcib.ttf) normal normal bold normal>,
#  <Font 'Gill Sans MT' (GIL_____.TTF) normal normal 400 normal>,
#  <Font 'Consolas' (consola.ttf) normal normal 400 normal>,
#  <Font 'Engravers MT' (ENGR.TTF) normal normal 400 normal>,
#  <Font 'Vani' (Vani.ttf) normal normal 400 normal>,
#  <Font 'Consolas' (consolai.ttf) italic normal 400 normal>,
#  <Font 'DilleniaUPC' (upcdb.ttf) normal normal bold normal>,
#  <Font 'AmeriGarmnd BT' (ENGARMI.TTF) italic normal 400 normal>,
#  <Font 'Myriad Pro' (MyriadPro-Cond.otf) normal normal 400 condensed>,
#  <Font 'SF Pro Display' (SF-Pro-Display-BlackItalic.otf) normal normal 400 normal>,
#  <Font 'Browallia New' (browaz.ttf) italic normal bold normal>,
#  <Font 'Arial' (ARIALNBI.TTF) italic normal bold condensed>,
#  <Font 'Adobe Kaiti Std' (AdobeKaitiStd-Regular.otf) normal normal 400 normal>,
#  <Font 'Georgia' (georgiaz.ttf) italic normal bold normal>,
#  <Font '????' (HMKMM.TTF) normal normal 400 normal>,
#  <Font 'Charlemagne Std' (CharlemagneStd-Bold.otf) normal normal bold normal>,
#  <Font 'Browallia New' (browa.ttf) normal normal 400 normal>,
#  <Font 'Trebuchet MS' (trebuc.ttf) normal normal 400 normal>,
#  <Font 'Niagara Engraved' (NIAGENG.TTF) normal normal 400 normal>,
#  <Font 'GoudyOlSt BT' (ENGDOSI.TTF) italic normal 400 normal>,
#  <Font 'Adobe Arabic' (AdobeArabic-Regular.otf) normal normal regular normal>,
#  <Font 'HYnamM' (HYNAMM.TTF) normal normal 400 normal>,
#  <Font 'Californian FB' (CALIFB.TTF) normal normal bold normal>,
#  <Font 'Segoe Print' (segoepr.ttf) normal normal 400 normal>,
#  <Font 'Georgia' (georgiai.ttf) italic normal 400 normal>,
#  <Font 'Segoe UI' (segoeui.ttf) normal normal 400 normal>,
#  <Font 'FrankRuehl' (frank.ttf) normal normal 400 normal>,
#  <Font 'LilyUPC' (upcli.ttf) italic normal 400 normal>,
#  <Font 'Harrington' (HARNGTON.TTF) normal normal 400 normal>,
#  <Font 'Harlow Solid Italic' (HARLOWSI.TTF) italic normal 400 normal>,
#  <Font 'Bookman Old Style' (BOOKOSB.TTF) normal normal book normal>,
#  <Font 'KodchiangUPC' (upckb.ttf) normal normal bold normal>,
#  <Font 'Yj GABI' (YGBI08.TTF) normal normal 400 normal>,
#  <Font 'Arabic Typesetting' (arabtype.ttf) normal normal 400 normal>,
#  <Font 'Perpetua' (PERI____.TTF) italic normal 400 normal>,
#  <Font 'Nueva Std' (NuevaStd-Cond.otf) normal normal 400 condensed>,
#  <Font 'YDIYGO360' (윤고딕360.ttf) normal normal 400 normal>,
#  <Font 'Vani' (Vanib.ttf) normal normal bold normal>,
#  <Font 'Maiandra GD' (MAIAN.TTF) normal normal 400 normal>,
#  <Font 'Calibri' (calibril.ttf) normal normal light normal>,
#  <Font 'Agency FB' (AGENCYR.TTF) normal normal 400 normal>,
#  <Font 'Trebuchet MS' (trebucbi.ttf) italic normal bold normal>,
#  <Font 'CommercialScript BT' (ENCOSCPT.TTF) italic normal 400 normal>,
#  <Font 'Calibri' (calibrib.ttf) normal normal bold normal>,
#  <Font 'Lao UI' (LaoUI.ttf) normal normal 400 normal>,
#  <Font 'Tw Cen MT Condensed' (TCCB____.TTF) normal normal bold condensed>,
#  <Font 'HYwulB' (HYWULB.TTF) normal normal 400 normal>,
#  <Font 'Stencil' (STENCIL.TTF) normal normal 400 normal>,
#  <Font 'Khmer UI' (KhmerUI.ttf) normal normal 400 normal>,
#  <Font 'Lucida Fax' (LFAXI.TTF) italic normal 400 normal>,
#  <Font 'Bodoni MT' (BOD_I.TTF) italic normal 400 normal>,
#  <Font 'Broadway' (BROADW.TTF) normal normal 400 normal>,
#  <Font 'Kozuka Mincho Pro' (KozMinPro-Bold.otf) normal normal 700 normal>,
#  <Font 'Arial' (ariali.ttf) italic normal 400 normal>,
#  <Font 'Arial' (ariblk.ttf) normal normal black normal>,
#  <Font 'Lucida Fax' (LFAXD.TTF) normal normal demibold normal>,
#  <Font 'Perpetua Titling MT' (PERTILI.TTF) normal normal light normal>,
#  <Font 'GoudyOlSt BT' (ENGDOSB.TTF) normal normal bold normal>,
#  <Font 'DaunPenh' (daunpenh.ttf) normal normal 400 normal>,
#  <Font 'Shonar Bangla' (Shonar.ttf) normal normal 400 normal>,
#  <Font 'Goudy Old Style' (GOUDOSI.TTF) italic normal 400 normal>,
#  <Font 'Pyunji R' (HMFMPYUN.TTF) normal normal 400 normal>,
#  <Font 'Showcard Gothic' (SHOWG.TTF) normal normal 400 normal>,
#  <Font 'David' (davidbd.ttf) normal normal bold normal>,
#  <Font 'Franklin Gothic Medium' (framdit.ttf) italic normal medium normal>,
#  <Font 'Bell MT' (BELL.TTF) normal normal 400 normal>,
#  <Font 'Haan Somang B' (HANSomaB.ttf) normal normal 400 normal>,
#  <Font 'Adobe Caslon Pro' (ACaslonPro-Regular.otf) normal normal 400 normal>,
#  <Font 'SF Pro Text' (SF-Pro-Text-LightItalic.otf) normal normal 400 normal>,
#  <Font 'FreesiaUPC' (upcfl.ttf) normal normal 400 normal>,
#  <Font 'Berlin Sans FB' (BRLNSR.TTF) normal normal 400 normal>,
#  <Font 'DilleniaUPC' (upcdl.ttf) normal normal 400 normal>,
#  <Font 'Kalinga' (kalingab.ttf) normal normal bold normal>,
#  <Font 'Headline R' (HMKMRHD.TTF) normal normal 400 normal>,
#  <Font 'Adobe Caslon Pro' (ACaslonPro-SemiboldItalic.otf) italic normal semibold normal>,
#  <Font 'Leelawadee' (leelawdb.ttf) normal normal bold normal>,
#  <Font 'Wingdings' (wingding.ttf) normal normal 400 normal>,
#  <Font 'Kozuka Gothic Pr6N' (KozGoPr6N-Heavy.otf) normal normal 700 normal>,
#  <Font 'Yj TEUNTEUN Bold' (YTTE08.TTF) normal normal 400 normal>,
#  <Font 'Mongolian Baiti' (monbaiti.ttf) normal normal 400 normal>,
#  <Font 'Microsoft JhengHei' (msjhbd.ttf) normal normal bold normal>,
#  <Font 'Orator10 BT' (ENORAT10.TTF) normal normal 400 normal>,
#  <Font 'Adobe Ming Std' (AdobeMingStd-Light.otf) normal normal 400 normal>,
#  <Font 'Segoe UI Symbol' (seguisym.ttf) normal normal 400 normal>,
#  <Font 'Poor Richard' (POORICH.TTF) normal normal 400 normal>,
#  <Font 'MV Boli' (mvboli.ttf) normal normal 400 normal>,
#  <Font 'Old English Text MT' (OLDENGL.TTF) normal normal 400 normal>,
#  <Font 'Wide Latin' (LATINWD.TTF) normal normal 400 expanded>,
#  <Font 'Rockwell Condensed' (ROCC____.TTF) normal normal 400 condensed>,
#  <Font 'BrowalliaUPC' (browaub.ttf) normal normal bold normal>,
#  <Font 'Blackadder ITC' (ITCBLKAD.TTF) normal normal black normal>,
#  <Font 'MS Reference Specialty' (REFSPCL.TTF) normal normal 400 normal>,
#  <Font 'Cambria' (cambriab.ttf) normal normal bold normal>,
#  <Font 'Yj SHANALL Medium ' (YSHN05.TTF) normal normal 400 normal>,
#  <Font 'Bodoni MT' (BOD_CB.TTF) normal normal bold condensed>,
#  <Font 'DilleniaUPC' (upcdbi.ttf) italic normal bold normal>,
#  <Font 'Chiller' (CHILLER.TTF) normal normal 400 normal>,
#  <Font 'Blippo Blk BT' (ENBLBK.TTF) normal normal 400 normal>,
#  <Font 'EucrosiaUPC' (upcei.ttf) italic normal 400 normal>,
#  <Font 'Yj DWMMOOGJO' (YDWM05.TTF) normal normal 400 normal>,
#  <Font 'Bodoni Bk BT' (ENBODBK.TTF) normal normal 400 normal>,
#  <Font 'Kokila' (kokilab.ttf) normal normal bold normal>,
#  <Font 'Berlin Sans FB Demi' (BRLNSDB.TTF) normal normal demi normal>,
#  <Font 'HCR Batang' (HANBatang.ttf) normal normal 400 normal>,
#  <Font 'Tw Cen MT Condensed Extra Bold' (TCCEB.TTF) normal normal bold condensed>,
#  <Font 'SF Pro Text' (SF-Pro-Text-Light.otf) normal normal 400 normal>,
#  <Font 'Papyrus' (PAPYRUS.TTF) normal normal 400 normal>,
#  <Font 'ahn2006-M' (ahn_m.ttf) normal normal 400 normal>,
#  <Font 'FuturaBlack BT' (ENFUTUBK.TTF) normal normal black normal>,
#  <Font 'Curlz MT' (CURLZ___.TTF) normal normal 400 normal>,
#  <Font 'Eras Light ITC' (ERASLGHT.TTF) normal normal light normal>,
#  <Font 'BrushScript BT' (ENBRUSH.TTF) italic normal 400 normal>,
#  <Font 'Lucida Sans Typewriter' (LTYPEB.TTF) normal normal bold normal>,
#  <Font 'Century Gothic' (GOTHICI.TTF) italic normal 400 normal>,
#  <Font 'Arial' (ARIALN.TTF) normal normal 400 condensed>,
#  <Font 'Kartika' (kartikab.ttf) normal normal bold normal>,
#  <Font 'SF Pro Display' (SF-Pro-Display-Light.otf) normal normal 400 normal>,
#  <Font 'Adobe Garamond Pro' (AGaramondPro-Bold.otf) normal normal bold normal>,
#  <Font 'CordiaUPC' (cordiaub.ttf) normal normal bold normal>,
#  <Font 'Nueva Std' (NuevaStd-BoldCondItalic.otf) italic normal bold condensed>,
#  <Font 'Orator Std' (OratorStd.otf) normal normal medium normal>,
#  <Font 'SimHei' (simhei.ttf) normal normal 400 normal>,
#  <Font 'Times New Roman' (timesi.ttf) italic normal roman normal>,
#  <Font 'YDIYGO340' (윤고딕340.ttf) normal normal 400 normal>,
#  <Font 'HYGraphic-Medium' (H2GPRM.TTF) normal normal 400 normal>,
#  <Font 'HYkanB' (HYKANB.TTF) normal normal 400 normal>,
#  <Font 'HYsupM' (HYSUPM.TTF) normal normal 400 normal>,
#  <Font 'Tahoma' (tahomabd.ttf) normal normal 700 normal>,
#  <Font '??????' (HMKBP.TTF) normal normal 700 normal>,
#  <Font 'Khmer UI' (KhmerUIb.ttf) normal normal bold normal>,
#  <Font 'Yj BUTGOT Light ' (YBUU02.TTF) normal normal 400 normal>,
#  <Font 'Adobe Caslon Pro' (ACaslonPro-Italic.otf) italic normal 400 normal>,
#  <Font 'Magic R' (HMKMMAG.TTF) normal normal 400 normal>,
#  <Font 'Stencil Std' (StencilStd.otf) normal normal bold normal>,
#  <Font 'Haan Sollip B' (HANSolB.ttf) normal normal 400 normal>,
#  <Font 'Angsana New' (angsai.ttf) italic normal 400 normal>,
#  <Font 'HYgprM' (HYGPRM.TTF) normal normal 400 normal>,
#  <Font 'Rage Italic' (RAGE.TTF) italic normal 400 normal>,
#  <Font 'AngsanaUPC' (angsau.ttf) normal normal 400 normal>,
#  <Font 'Verdana' (verdanab.ttf) normal normal bold normal>,
#  <Font 'Adobe Garamond Pro' (AGaramondPro-BoldItalic.otf) italic normal bold normal>,
#  <Font 'Kalinga' (kalinga.ttf) normal normal 400 normal>,
#  <Font 'Palatino Linotype' (palai.ttf) italic normal 400 normal>,
#  <Font 'HYcysM' (HYCYSM.TTF) normal normal 400 normal>,
#  <Font 'Lucida Fax' (LFAX.TTF) normal normal regular normal>,
#  <Font 'Simplified Arabic' (simpbdo.ttf) normal normal bold normal>,
#  <Font 'Lucida Sans Typewriter' (LTYPE.TTF) normal normal regular normal>,
#  <Font 'Blackoak Std' (BlackoakStd.otf) normal normal black normal>,
#  <Font 'HYgsrB' (HYGSRB.TTF) normal normal 400 normal>,
#  <Font 'HYPost-Medium' (H2PORM.TTF) normal normal 400 normal>,
#  <Font 'Lao UI' (LaoUIb.ttf) normal normal bold normal>,
#  <Font 'Letter Gothic Std' (LetterGothicStd.otf) normal normal medium normal>,
#  <Font 'Hobo Std' (HoboStd.otf) normal normal medium normal>,
#  <Font 'Ravie' (RAVIE.TTF) normal normal 400 normal>,
#  <Font 'CentSchbook BT' (ENCSCHB.TTF) normal normal book normal>,
#  <Font 'Microsoft PhagsPa' (phagspab.ttf) normal normal bold normal>,
#  <Font 'Malgun Gothic' (malgun.ttf) normal normal 400 normal>,
#  <Font 'Shruti' (shruti.ttf) normal normal 400 normal>,
#  <Font '??????' (HMKBS.TTF) normal normal 700 normal>,
#  <Font 'Nueva Std' (NuevaStd-BoldCond.otf) normal normal bold condensed>,
#  <Font 'ahn2006-B' (ahn_b.ttf) normal normal 400 normal>,
#  <Font 'Calisto MT' (CALISTBI.TTF) italic normal bold normal>,
#  <Font 'HYwulM' (HYWULM.TTF) normal normal 400 normal>,
#  <Font 'Snap ITC' (SNAP____.TTF) normal normal 400 normal>,
#  <Font 'Kartika' (kartika.ttf) normal normal 400 normal>,
#  <Font 'French Script MT' (FRSCRIPT.TTF) normal normal 400 normal>,
#  <Font 'Rockwell' (ROCKBI.TTF) italic normal bold normal>,
#  <Font 'Bodoni MT' (BOD_BI.TTF) italic normal bold normal>,
#  <Font 'Myriad Pro' (MyriadPro-It.otf) italic normal 400 normal>,
#  <Font 'Sakkal Majalla' (majallab.ttf) normal normal bold normal>,
#  <Font 'Kozuka Mincho Pr6N' (KozMinPr6N-Light.otf) normal normal 400 normal>,
#  <Font 'SAPIcons' (sapin.ttf) normal normal normal normal>,
#  <Font 'FreesiaUPC' (upcfb.ttf) normal normal bold normal>,
#  <Font 'Gill Sans MT' (GILI____.TTF) italic normal 400 normal>,
#  <Font 'Letter Gothic Std' (LetterGothicStd-Bold.otf) normal normal bold normal>,
#  <Font 'Gill Sans MT Ext Condensed Bold' (GLSNECB.TTF) normal normal bold condensed>,
#  <Font 'Calibri' (calibri.ttf) normal normal 400 normal>,
#  <Font 'HYkanM' (HYKANM.TTF) normal normal 400 normal>,
#  <Font 'EucrosiaUPC' (upcel.ttf) normal normal 400 normal>,
#  <Font 'Utsaah' (utsaahbi.ttf) italic normal bold normal>,
#  <Font 'Century Gothic' (GOTHICBI.TTF) italic normal bold normal>,
#  <Font 'Kozuka Gothic Pr6N' (KozGoPr6N-Regular.otf) normal normal 400 normal>,
#  <Font 'Yj BLOCK Medium' (YBLO05.TTF) normal normal 400 normal>,
#  <Font 'Bodoni Bd BT' (ENBODB.TTF) normal normal 400 normal>,
#  <Font 'Franklin Gothic Book' (FRABKIT.TTF) italic normal book normal>,
#  <Font '????' (HMKMOLD.TTF) normal normal 400 normal>,
#  <Font 'SF Pro Display' (SF-Pro-Display-MediumItalic.otf) normal normal 400 normal>,
#  <Font 'Courier New' (courbi.ttf) italic normal bold normal>,
#  <Font 'Calisto MT' (CALIST.TTF) normal normal 400 normal>,
#  <Font 'High Tower Text' (HTOWERTI.TTF) italic normal 400 normal>,
#  <Font 'MJemokGothic' (MK.TTF) normal normal 400 normal>,
#  <Font 'SF Pro Text' (SF-Pro-Text-SemiboldItalic.otf) normal normal 400 normal>,
#  <Font 'Consolas' (consolab.ttf) normal normal bold normal>,
#  <Font 'Modern No. 20' (MOD20.TTF) normal normal 400 normal>,
#  <Font 'BrowalliaUPC' (browaui.ttf) italic normal 400 normal>,
#  <Font 'Courier New' (couri.ttf) italic normal 400 normal>,
#  <Font 'SF Pro Display' (SF-Pro-Display-Heavy.otf) normal normal 400 normal>,
#  <Font 'MDGaesung' (Gaesung.ttf) normal normal 400 normal>,
#  <Font 'Simplified Arabic' (simpo.ttf) normal normal 400 normal>,
#  <Font 'Segoe UI' (segoeuib.ttf) normal normal 700 normal>,
#  <Font 'Book Antiqua' (ANTQUABI.TTF) italic normal book normal>,
#  <Font 'LilyUPC' (upcll.ttf) normal normal 400 normal>,
#  <Font 'HCR Dotum Ext' (HANDotumExt.ttf) normal normal 400 normal>,
#  <Font 'Informal Roman' (INFROMAN.TTF) normal normal roman normal>,
#  <Font 'Playbill' (PLAYBILL.TTF) normal normal 400 normal>,
#  <Font 'SF Pro Text' (SF-Pro-Text-Semibold.otf) normal normal 400 normal>,
#  <Font 'Minion Pro' (MinionPro-SemiboldIt.otf) italic normal semibold normal>,
#  <Font 'Freehand591 BT' (ENFREEHD.TTF) normal normal 400 normal>,
#  <Font 'Kozuka Gothic Pr6N' (KozGoPr6N-Light.otf) normal normal 400 normal>,
#  <Font 'Kozuka Gothic Pr6N' (KozGoPr6N-Bold.otf) normal normal 700 normal>,
#  <Font 'Tw Cen MT' (TCM_____.TTF) normal normal 400 normal>,
#  <Font 'Courier New' (cour.ttf) normal normal 400 normal>,
#  <Font 'SF Pro Text' (SF-Pro-Text-Medium.otf) normal normal 400 normal>,
#  <Font 'Yj BACDOO Bold ' (YDOO08.TTF) normal normal 400 normal>,
#  <Font 'Impact' (impact.ttf) normal normal 400 normal>,
#  <Font 'MGungJeong' (MJ.TTF) normal normal 400 normal>,
#  <Font '??????' (HMKMA.TTF) normal normal 400 normal>,
#  <Font 'LilyUPC' (upclb.ttf) normal normal bold normal>,
#  <Font 'Poplar Std' (PoplarStd.otf) normal normal black normal>,
#  <Font 'Bradley Hand ITC' (BRADHITC.TTF) normal normal 400 normal>,
#  <Font 'Agency FB' (AGENCYB.TTF) normal normal bold normal>,
#  <Font 'Freestyle Script' (FREESCPT.TTF) normal normal 400 normal>,
#  <Font 'Microsoft JhengHei' (msjh.ttf) normal normal 400 normal>,
#  <Font 'Franklin Gothic Demi Cond' (FRADMCN.TTF) normal normal demi condensed>,
#  <Font 'HYPost-Light' (H2PORL.TTF) normal normal 400 normal>,
#  <Font 'HYHeadLine M' (H2HDRM.TTF) normal normal 400 normal>,
#  <Font 'Calisto MT' (CALISTB.TTF) normal normal bold normal>,
#  <Font 'HYporM' (HYPORM.TTF) normal normal 400 normal>,
#  <Font 'BernhardFashion BT' (ENBERNF.TTF) normal normal 400 normal>,
#  <Font 'Kokila' (kokila.ttf) normal normal 400 normal>,
#  <Font 'Myriad Pro' (MyriadPro-BoldIt.otf) italic normal bold normal>,
#  <Font 'SF Pro Display' (SF-Pro-Display-Bold.otf) normal normal 400 normal>,
#  <Font 'Tekton Pro' (TektonPro-BoldObl.otf) oblique normal bold normal>,
#  <Font 'Rockwell' (ROCKI.TTF) italic normal 400 normal>,
#  <Font 'KodchiangUPC' (upckbi.ttf) italic normal bold normal>,
#  <Font 'SAPDings' (sapdn.ttf) normal normal normal normal>,
#  <Font 'Haansoft Dotum' (HDOTUM.TTF) normal normal 400 normal>,
#  <Font 'MDArt' (Art.ttf) normal normal 400 normal>,
#  <Font 'CordiaUPC' (cordiau.ttf) normal normal 400 normal>,
#  <Font 'Perpetua' (PERB____.TTF) normal normal bold normal>,
#  <Font 'Nueva Std' (NuevaStd-CondItalic.otf) italic normal 400 condensed>,
#  <Font 'YJ INJANG Medium' (YINJ05.TTF) normal normal 400 normal>,
#  <Font 'Adobe Gothic Std' (AdobeGothicStd-Bold.otf) normal normal 700 normal>,
#  <Font 'BroadwayEngraved BT' (ENBRODWY.TTF) normal normal 400 normal>,
#  <Font 'MSugiHeulim' (MP.TTF) normal normal 400 normal>,
#  <Font 'Courier10 BT' (ENCR10BI.TTF) italic normal bold normal>,
#  <Font 'MT Extra' (mtextra.ttf) normal normal 400 normal>,
#  <Font 'Vladimir Script' (VLADIMIR.TTF) normal normal 400 normal>,
#  <Font 'Tekton Pro' (TektonPro-BoldCond.otf) normal normal bold condensed>,
#  <Font 'Tw Cen MT' (TCB_____.TTF) normal normal bold normal>,
#  <Font 'MDotum' (MG.TTF) normal normal 400 normal>,
#  <Font 'Onyx' (ONYX.TTF) normal normal 400 normal>,
#  <Font 'Birch Std' (BirchStd.otf) normal normal 400 normal>,
#  <Font 'Monotype Corsiva' (MTCORSVA.TTF) normal normal 400 normal>,
#  <Font 'Matura MT Script Capitals' (MATURASC.TTF) normal normal 400 normal>,
#  <Font 'SF Pro Display' (SF-Pro-Display-Regular.otf) normal normal 400 normal>,
#  <Font 'Californian FB' (CALIFR.TTF) normal normal 400 normal>,
#  <Font 'Forte' (FORTE.TTF) normal normal 400 normal>,
#  <Font 'Century Schoolbook' (SCHLBKBI.TTF) italic normal book normal>,
#  <Font 'Estrangelo Edessa' (estre.ttf) normal normal 400 normal>,
#  <Font 'Bodoni MT' (BOD_CI.TTF) italic normal 400 condensed>,
#  <Font 'Franklin Gothic Heavy' (FRAHV.TTF) normal normal heavy normal>,
#  <Font 'Bodoni MT' (BOD_BLAI.TTF) italic normal black normal>,
#  <Font 'Haan Sale B' (HANSaleB.ttf) normal normal 400 normal>,
#  <Font 'Adobe Caslon Pro' (ACaslonPro-Bold.otf) normal normal bold normal>,
#  <Font 'SF Pro Display' (SF-Pro-Display-UltralightItalic.otf) normal normal 400 normal>,
#  <Font 'SamsungImagination Modern' (SamsungImaginationModernRegular.otf) normal normal 400 normal>,
#  <Font 'Haan Baekje M' (HANBaekM.ttf) normal normal 400 normal>,
#  <Font 'Century Gothic' (GOTHIC.TTF) normal normal 400 normal>,
#  <Font 'MGungHeulim' (MM.TTF) normal normal 400 normal>,
#  <Font 'Adobe Hebrew' (AdobeHebrew-Bold.otf) normal normal bold normal>,
#  <Font 'Georgia' (georgia.ttf) normal normal 400 normal>,
#  <Font 'Cooper Std' (CooperBlackStd.otf) normal normal black normal>,
#  <Font 'Kozuka Mincho Pro' (KozMinPro-Medium.otf) normal normal 400 normal>,
#  <Font 'Haettenschweiler' (HATTEN.TTF) normal normal 400 normal>,
#  <Font 'Raavi' (raavib.ttf) normal normal bold normal>,
#  <Font 'Kozuka Gothic Pro' (KozGoPro-Light.otf) normal normal 400 normal>,
#  <Font 'Lucida Fax' (LFAXDI.TTF) italic normal demibold normal>,
#  <Font 'Minion Pro' (MinionPro-BoldIt.otf) italic normal bold normal>,
#  <Font 'EucrosiaUPC' (upcebi.ttf) italic normal bold normal>,
#  <Font 'Gill Sans MT Condensed' (GILC____.TTF) normal normal 400 condensed>,
#  <Font 'Adobe Myungjo Std' (AdobeMyungjoStd-Medium.otf) normal normal 400 normal>,
#  <Font 'AngsanaUPC' (angsauz.ttf) italic normal bold normal>,
#  <Font 'David' (david.ttf) normal normal 400 normal>,
#  <Font 'HYtbrB' (HYTBRB.TTF) normal normal 400 normal>,
#  <Font 'Tw Cen MT Condensed' (TCCM____.TTF) normal normal 400 condensed>,
#  <Font 'MDAlong' (Along.ttf) normal normal 400 normal>,
#  <Font 'Angsana New' (angsa.ttf) normal normal 400 normal>,
#  <Font 'Bodoni MT' (BOD_BLAR.TTF) normal normal black normal>,
#  <Font 'Webdings' (webdings.ttf) normal normal 400 normal>,
#  <Font 'Bodoni MT' (BOD_CBI.TTF) italic normal bold condensed>,
#  <Font 'SF Pro Display' (SF-Pro-Display-LightItalic.otf) normal normal 400 normal>,
#  <Font 'Wingdings 3' (WINGDNG3.TTF) normal normal 400 normal>,
#  <Font 'Yj NANCHO Medium' (YNCH05.TTF) normal normal 400 normal>,
#  <Font '??????' (HMKMP.TTF) normal normal 400 normal>,
#  <Font 'Lucida Bright' (LBRITEDI.TTF) italic normal demibold normal>,
#  <Font 'Adobe Hebrew' (AdobeHebrew-BoldItalic.otf) italic normal bold normal>,
#  <Font 'Candara' (Candarai.ttf) italic normal 400 normal>,
#  <Font 'Gautami' (gautami.ttf) normal normal 400 normal>,
#  <Font 'Leelawadee' (leelawad.ttf) normal normal 400 normal>,
#  <Font 'Haan Sollip M' (HANSolM.ttf) normal normal 400 normal>,
#  <Font 'Rockwell' (ROCK.TTF) normal normal 400 normal>,
#  <Font 'Franklin Gothic Demi' (FRADM.TTF) normal normal demi normal>,
#  <Font 'Miriam' (mriam.ttf) normal normal 400 normal>,
#  <Font 'Algerian' (ALGER.TTF) normal normal 400 normal>,
#  <Font 'Garamond' (GARA.TTF) normal normal 400 normal>,
#  <Font 'JasmineUPC' (upcjbi.ttf) italic normal bold normal>,
#  <Font 'Symbol' (symbol.ttf) normal normal 400 normal>,
#  <Font 'BrowalliaUPC' (browauz.ttf) italic normal bold normal>,
#  <Font 'MoolBoran' (moolbor.ttf) normal normal 400 normal>,
#  <Font 'HYMyeongJo-Extra' (H2MJRE.TTF) normal normal 400 normal>,
#  <Font 'Eras Demi ITC' (ERASDEMI.TTF) normal normal demi normal>,
#  <Font 'Microsoft Sans Serif' (micross.ttf) normal normal 400 normal>,
#  <Font '??????' (HMKLP.TTF) normal normal 400 normal>,
#  <Font 'Parchment' (PARCHM.TTF) normal normal 400 normal>,
#  <Font 'Kozuka Gothic Pro' (KozGoPro-Regular.otf) normal normal 400 normal>,
#  <Font 'Adobe Garamond Pro' (AGaramondPro-Regular.otf) normal normal 400 normal>,
#  <Font 'Cambria' (cambriai.ttf) italic normal 400 normal>,
#  <Font 'Perpetua Titling MT' (PERTIBD.TTF) normal normal bold normal>,
#  <Font 'Arial' (arial.ttf) normal normal 400 normal>,
#  <Font 'Simplified Arabic Fixed' (simpfxo.ttf) normal normal 400 normal>,
#  <Font 'Angsana New' (angsab.ttf) normal normal bold normal>,
#  <Font 'Trajan Pro' (TrajanPro-Bold.otf) normal normal bold normal>,
#  <Font 'Tempus Sans ITC' (TEMPSITC.TTF) normal normal 400 normal>,
#  <Font 'Constantia' (constani.ttf) italic normal 400 normal>,
#  <Font 'Bodoni MT' (BOD_CR.TTF) normal normal 400 condensed>,
#  <Font 'Bernard MT Condensed' (BERNHC.TTF) normal normal 400 condensed>,
#  <Font 'Kozuka Mincho Pr6N' (KozMinPr6N-ExtraLight.otf) normal normal 400 normal>,
#  <Font 'Consolas' (consolaz.ttf) italic normal bold normal>,
#  <Font 'Kozuka Mincho Pr6N' (KozMinPr6N-Bold.otf) normal normal 700 normal>,
#  <Font 'Perpetua' (PERBI___.TTF) italic normal bold normal>,
#  <Font 'Kunstler Script' (KUNSTLER.TTF) normal normal 400 normal>,
#  <Font 'Palace Script MT' (PALSCRI.TTF) normal normal 400 normal>,
#  <Font 'DilleniaUPC' (upcdi.ttf) italic normal 400 normal>,
#  <Font 'Franklin Gothic Heavy' (FRAHVIT.TTF) italic normal heavy normal>,
#  <Font 'Myriad Pro' (MyriadPro-BoldCondIt.otf) italic normal bold condensed>,
#  <Font 'BrowalliaUPC' (browau.ttf) normal normal 400 normal>,
#  <Font 'Century Schoolbook' (CENSCBK.TTF) normal normal book normal>,
#  <Font 'GoudyOlSt BT' (ENGDOSBI.TTF) italic normal bold normal>,
#  <Font 'Kokila' (kokilai.ttf) italic normal 400 normal>,
#  <Font 'Times New Roman' (timesbd.ttf) normal normal roman normal>,
#  <Font 'Centaur' (CENTAUR.TTF) normal normal 400 normal>,
#  <Font 'Mangal' (mangal.ttf) normal normal 400 normal>,
#  <Font 'Aparajita' (aparajb.ttf) normal normal bold normal>,
#  <Font 'Gill Sans Ultra Bold' (GILSANUB.TTF) normal normal bold normal>,
#  <Font 'Verdana' (verdanaz.ttf) italic normal bold normal>,
#  <Font 'MBatang' (MT.TTF) normal normal 400 normal>,
#  <Font 'Haan Somang M' (HANSomaM.ttf) normal normal 400 normal>,
#  <Font 'Microsoft PhagsPa' (phagspa.ttf) normal normal 400 normal>,
#  <Font 'MJemokBatang' (MB.TTF) normal normal 400 normal>,
#  <Font 'MS Reference Sans Serif' (REFSAN.TTF) normal normal 400 normal>,
#  <Font 'Microsoft Uighur' (msuighur.ttf) normal normal 400 normal>,
#  <Font 'Ami R' (HMKMAMI.TTF) normal normal 400 normal>,
#  <Font 'OCR-B-10 BT' (ENOCRB10.TTF) normal normal 400 normal>,
#  <Font 'Adobe Arabic' (AdobeArabic-Bold.otf) normal normal bold normal>,
#  <Font 'HYsupB' (HYSUPB.TTF) normal normal 400 normal>,
#  <Font 'Sakkal Majalla' (majalla.ttf) normal normal 400 normal>,
#  <Font 'Haan Sale M' (HANSaleM.ttf) normal normal 400 normal>,
#  <Font 'Yj BONMOKGAK Medium ' (YBMG05.TTF) normal normal 400 normal>,
#  <Font 'YDIYGO310' (윤고딕310.ttf) normal normal 400 normal>,
#  <Font 'KaiTi' (simkai.ttf) normal normal 400 normal>,
#  <Font '????' (HMKMG.TTF) normal normal 400 normal>,
#  <Font 'Arial' (arialbi.ttf) italic normal bold normal>,
#  <Font 'Segoe UI' (segoeuil.ttf) normal normal 400 normal>,
#  <Font 'Brush Script Std' (BrushScriptStd.otf) normal normal medium normal>,
#  <Font 'Raavi' (raavi.ttf) normal normal 400 normal>,
#  <Font 'Bodoni MT' (BOD_R.TTF) normal normal 400 normal>,
#  <Font 'OCR A Std' (OCRAStd.otf) normal normal 400 normal>,
#  <Font 'Cooper Blk BT' (ENCOBK.TTF) normal normal 400 normal>,
#  <Font 'Arial' (ARIALNB.TTF) normal normal bold condensed>,
#  <Font 'Nyala' (nyala.ttf) normal normal 400 normal>,
#  <Font 'Comic Sans MS' (comic.ttf) normal normal 400 normal>,
#  <Font 'Kozuka Mincho Pro' (KozMinPro-Light.otf) normal normal 400 normal>,
#  <Font 'AngsanaUPC' (angsaub.ttf) normal normal bold normal>,
#  <Font 'Georgia' (georgiab.ttf) normal normal bold normal>,
#  <Font 'HYhaeseo' (UNI_HSR.TTF) normal normal 400 normal>,
#  <Font '??????' (HMKLA.TTF) normal normal 400 normal>,
#  <Font 'CordiaUPC' (cordiauz.ttf) italic normal bold normal>,
#  <Font 'Corbel' (corbelz.ttf) italic normal bold normal>,
#  <Font 'Bell MT' (BELLI.TTF) italic normal 400 normal>,
#  <Font 'Haan Baekje B' (HANBaekB.ttf) normal normal 400 normal>,
#  <Font 'YDIYGO320' (윤고딕320.ttf) normal normal 400 normal>,
#  <Font 'HYSinMyeongJo-Medium' (H2MJSM.TTF) normal normal 400 normal>,
#  <Font 'Lucida Sans' (LSANSDI.TTF) italic normal demibold normal>,
#  <Font 'SF Pro Text' (SF-Pro-Text-Heavy.otf) normal normal 400 normal>,
#  <Font 'Tekton Pro' (TektonPro-Bold.otf) normal normal bold normal>,
#  <Font 'Book Antiqua' (ANTQUAB.TTF) normal normal book normal>,
#  <Font 'FreesiaUPC' (upcfi.ttf) italic normal 400 normal>,
#  <Font 'Franklin Gothic Demi' (FRADMIT.TTF) italic normal demi normal>,
#  <Font 'Rockwell Condensed' (ROCCB___.TTF) normal normal bold condensed>,
#  <Font 'Baskerville BT' (ENBASKVL.TTF) normal normal 400 normal>,
#  <Font 'Chaparral Pro' (ChaparralPro-Regular.otf) normal normal 400 normal>,
#  <Font 'Kozuka Gothic Pr6N' (KozGoPr6N-ExtraLight.otf) normal normal 400 normal>,
#  <Font 'Mistral' (MISTRAL.TTF) normal normal 400 normal>,
#  <Font 'SF Pro Display' (SF-Pro-Display-Semibold.otf) normal normal 400 normal>,
#  <Font 'HYbsrB' (HYBSRB.TTF) normal normal 400 normal>,
#  <Font 'HCR Dotum' (HANDotum.ttf) normal normal 400 normal>,
#  <Font 'Adobe Caslon Pro' (ACaslonPro-Semibold.otf) normal normal semibold normal>,
#  <Font 'Vrinda' (vrindab.ttf) normal normal bold normal>,
#  <Font 'Haansoft Batang' (HBATANG.TTF) normal normal 400 normal>,
#  <Font 'KodchiangUPC' (upcki.ttf) italic normal 400 normal>,
#  <Font 'Trajan Pro' (TrajanPro-Regular.otf) normal normal 400 normal>,
#  <Font 'LilyUPC' (upclbi.ttf) italic normal bold normal>,
#  <Font 'Constantia' (constan.ttf) normal normal 400 normal>,
#  <Font 'Adobe Hebrew' (AdobeHebrew-Regular.otf) normal normal regular normal>,
#  <Font 'Jokerman' (JOKERMAN.TTF) normal normal 400 normal>,
#  <Font 'Lucida Sans' (LSANSD.TTF) normal normal roman normal>,
#  <Font 'DomCasual BT' (ENDOMCA.TTF) normal normal 400 normal>,
#  <Font '??????' (HMKLS.TTF) normal normal 400 normal>,
#  <Font 'Utsaah' (utsaahb.ttf) normal normal bold normal>,
#  <Font 'Script MT Bold' (SCRIPTBL.TTF) normal normal bold normal>,
#  <Font 'Times New Roman' (timesbi.ttf) italic normal roman normal>,
#  <Font 'Haan Cooljazz B' (HANCooljazzB.ttf) normal normal 400 normal>,
#  <Font 'Britannic Bold' (BRITANIC.TTF) normal normal bold normal>,
#  <Font 'Mangal' (mangalb.ttf) normal normal bold normal>,
#  <Font 'Corbel' (corbel.ttf) normal normal 400 normal>,
#  <Font 'Myriad Pro' (MyriadPro-Regular.otf) normal normal 400 normal>,
#  <Font 'HYsanB' (HYSANB.TTF) normal normal 400 normal>,
#  <Font 'Wingdings 2' (WINGDNG2.TTF) normal normal 400 normal>,
#  <Font 'Swis721 BT' (ENS721LI.TTF) italic normal 400 normal>,
#  <Font 'HCR Batang' (HANBatangB.ttf) normal normal bold normal>,
#  <Font 'Latha' (lathab.ttf) normal normal bold normal>,
#  <Font 'Stencil BT' (ENSTEN.TTF) normal normal 400 normal>,
#  <Font '??????' (HMKBA.TTF) normal normal 400 normal>,
#  <Font 'Courier New' (courbd.ttf) normal normal bold normal>,
#  <Font 'SF Pro Display' (SF-Pro-Display-HeavyItalic.otf) normal normal 400 normal>,
#  <Font 'Palatino Linotype' (palabi.ttf) italic normal bold normal>,
#  <Font 'Kozuka Gothic Pr6N' (KozGoPr6N-Medium.otf) normal normal 400 normal>,
#  <Font 'SF Pro Text' (SF-Pro-Text-Regular.otf) normal normal 400 normal>,
#  <Font 'IrisUPC' (upcil.ttf) normal normal 400 normal>,
#  <Font 'Chaparral Pro' (ChaparralPro-Bold.otf) normal normal bold normal>,
#  <Font 'Bookman Old Style' (BOOKOS.TTF) normal normal book normal>,
#  <Font 'Kozuka Mincho Pr6N' (KozMinPr6N-Heavy.otf) normal normal 700 normal>,
#  <Font 'Lucida Bright' (LBRITED.TTF) normal normal demibold normal>,
#  <Font 'Vijaya' (vijayab.ttf) normal normal bold normal>,
#  <Font 'IrisUPC' (upcii.ttf) italic normal 400 normal>,
#  <Font 'Garamond' (GARABD.TTF) normal normal bold normal>,
#  <Font 'Courier10 BT' (ENCR10B.TTF) normal normal bold normal>,
#  <Font 'Minion Pro' (MinionPro-Regular.otf) normal normal 400 normal>,
#  <Font 'Chaparral Pro' (ChaparralPro-Italic.otf) italic normal 400 normal>,
#  <Font 'Adobe Arabic' (AdobeArabic-Italic.otf) italic normal 400 normal>,
#  <Font 'HYGothic-Extra' (H2GTRE.TTF) normal normal 400 normal>,
#  <Font 'Lithos Pro' (LithosPro-Black.otf) normal normal black normal>,
#  <Font 'Goudy Stout' (GOUDYSTO.TTF) normal normal 400 normal>,
#  <Font 'HYsnrL' (HYSNRL.TTF) normal normal 400 normal>,
#  <Font 'SF Pro Display' (SF-Pro-Display-Black.otf) normal normal 400 normal>,
#  <Font 'Calibri' (calibriz.ttf) italic normal bold normal>,
#  <Font 'Minion Pro' (MinionPro-Semibold.otf) normal normal semibold normal>,
#  <Font 'Corbel' (corbelb.ttf) normal normal bold normal>,
#  <Font 'Cordia New' (cordia.ttf) normal normal 400 normal>,
#  <Font '??????' (HMKMS.TTF) normal normal 400 normal>,
#  <Font 'Utsaah' (utsaahi.ttf) italic normal 400 normal>,
#  <Font 'Myriad Pro' (MyriadPro-Semibold.otf) normal normal semibold normal>,
#  <Font 'Lucida Sans Unicode' (l_10646.ttf) normal normal 400 normal>,
#  <Font 'HCR Dotum' (HANDotumB.ttf) normal normal bold normal>,
#  <Font 'Kozuka Mincho Pr6N' (KozMinPr6N-Medium.otf) normal normal 400 normal>,
#  <Font 'JasmineUPC' (upcji.ttf) italic normal 400 normal>,
#  <Font 'Kozuka Gothic Pro' (KozGoPro-ExtraLight.otf) normal normal 400 normal>,
#  <Font 'Cooper Black' (COOPBL.TTF) normal normal black normal>,
#  <Font 'Euphemia' (euphemia.ttf) normal normal 400 normal>,
#  <Font 'Tw Cen MT' (TCMI____.TTF) italic normal 400 normal>,
#  <Font 'Yet R' (HMFMOLD.TTF) normal normal 400 normal>,
#  <Font 'Gigi' (GIGI.TTF) normal normal 400 normal>,
#  <Font 'Calibri' (calibrili.ttf) italic normal light normal>,
#  <Font 'Adobe Fan Heiti Std' (AdobeFanHeitiStd-Bold.otf) normal normal 700 normal>,
#  <Font 'Arial monospaced for SAP' (arimonbd.ttf) normal normal bold normal>,
#  <Font 'Trebuchet MS' (trebucit.ttf) italic normal 400 normal>,
#  <Font 'HYShortSamul-Medium' (H2SA1M.TTF) normal normal 400 normal>,
#  <Font 'Prestige Elite Std' (PrestigeEliteStd-Bd.otf) normal normal bold normal>,
#  <Font 'Ebrima' (ebrimabd.ttf) normal normal 700 normal>,
#  <Font '3 of 9 Barcode' (3of9_new.ttf) normal normal 400 normal>,
#  <Font 'HYmjrE' (HYMJRE.TTF) normal normal 400 normal>,
#  <Font 'Arial Rounded MT Bold' (ARLRDBD.TTF) normal normal bold normal>,
#  <Font 'Goudy Old Style' (GOUDOSB.TTF) normal normal bold normal>,
#  <Font 'Iskoola Pota' (iskpotab.ttf) normal normal bold normal>,
#  <Font 'Haan Cooljazz M' (HANCooljazzM.ttf) normal normal 400 normal>,
#  <Font 'Minion Pro' (MinionPro-Medium.otf) normal normal medium normal>,
#  <Font 'Lucida Bright' (LBRITEI.TTF) italic normal 400 normal>,
#  <Font 'Ebrima' (ebrima.ttf) normal normal 400 normal>,
#  <Font 'Lucida Sans' (LSANS.TTF) normal normal regular normal>,
#  <Font 'Yj CHMSOOT Bold' (YCHM08.TTF) normal normal 400 normal>,
#  <Font 'Trebuchet MS' (trebucbd.ttf) normal normal bold normal>,
#  <Font 'Liberty BT' (ENLIBRTY.TTF) italic normal 400 normal>,
#  <Font 'Footlight MT Light' (FTLTLT.TTF) normal normal light normal>,
#  <Font 'Newtext Bk BT' (ENITCNBK.TTF) normal normal 400 normal>,
#  <Font 'Rockwell' (ROCKB.TTF) normal normal bold normal>,
#  <Font 'Copperplate Gothic Light' (COPRGTL.TTF) normal normal light normal>,
#  <Font 'AmeriGarmnd BT' (ENGARM.TTF) normal normal 400 normal>,
#  <Font 'Segoe UI' (segoeuiz.ttf) italic normal 700 normal>,
#  <Font 'Candara' (Candarab.ttf) normal normal bold normal>,
#  <Font 'HYnamB' (HYNAMB.TTF) normal normal 400 normal>,
#  <Font 'Eras Medium ITC' (ERASMD.TTF) normal normal medium normal>,
#  <Font 'Adobe Heiti Std' (AdobeHeitiStd-Regular.otf) normal normal 400 normal>,
#  <Font '???' (PENHL.TTF) normal normal 400 normal>,
#  <Font 'Verdana' (verdanai.ttf) italic normal 400 normal>,
#  <Font 'MDSol' (Sol.ttf) normal normal 400 normal>,
#  <Font 'Lithos Pro' (LithosPro-Regular.otf) normal normal 400 normal>,
#  <Font 'Candara' (Candara.ttf) normal normal 400 normal>,
#  <Font 'Aparajita' (aparaji.ttf) italic normal 400 normal>,
#  <Font 'Lucida Bright' (LBRITE.TTF) normal normal 400 normal>,
#  <Font 'KodchiangUPC' (upckl.ttf) normal normal 400 normal>,
#  <Font 'SF Pro Text' (SF-Pro-Text-Bold.otf) normal normal 400 normal>,
#  <Font 'Lucida Sans Typewriter' (LTYPEBO.TTF) oblique normal bold normal>,
#  <Font 'Marlett' (marlett.ttf) normal normal 400 normal>,
#  <Font 'Myriad Pro' (MyriadPro-CondIt.otf) italic normal 400 condensed>,
#  <Font 'SF Pro Display' (SF-Pro-Display-Medium.otf) normal normal 400 normal>,
#  <Font 'Corbel' (corbeli.ttf) italic normal 400 normal>,
#  <Font 'CentSchbook BT' (ENCSCH.TTF) normal normal book normal>,
#  <Font 'Book Antiqua' (BKANT.TTF) normal normal book normal>,
#  <Font 'Elephant' (ELEPHNT.TTF) normal normal 400 normal>,
#  <Font 'Plantagenet Cherokee' (plantc.ttf) normal normal 400 normal>,
#  <Font 'Californian FB' (CALIFI.TTF) italic normal 400 normal>,
#  <Font 'JasmineUPC' (upcjb.ttf) normal normal bold normal>,
#  <Font 'Browallia New' (browab.ttf) normal normal bold normal>,
#  <Font 'Gautami' (gautamib.ttf) normal normal bold normal>,
#  <Font 'Baskerville Old Face' (BASKVILL.TTF) normal normal 400 normal>,
#  <Font 'Iskoola Pota' (iskpota.ttf) normal normal 400 normal>,
#  <Font 'Microsoft YaHei' (msyhbd.ttf) normal normal bold normal>,
#  <Font 'MDEasop' (Easop.ttf) normal normal 400 normal>,
#  <Font 'Orbit-B BT' (ENORBITB.TTF) normal normal 400 normal>,
#  <Font '? ??' (TAENMR.TTF) normal normal 400 normal>,
#  <Font 'Myriad Pro' (MyriadPro-BoldCond.otf) normal normal bold condensed>,
#  <Font 'Letter Gothic Std' (LetterGothicStd-Slanted.otf) italic normal 400 normal>,
#  <Font 'Century Schoolbook' (SCHLBKB.TTF) normal normal book normal>,
#  <Font 'Verdana' (verdana.ttf) normal normal 400 normal>,
#  <Font 'Utsaah' (utsaah.ttf) normal normal 400 normal>,
#  <Font 'Bookman Old Style' (BOOKOSBI.TTF) italic normal book normal>,
#  <Font 'MHunmin' (MH.TTF) normal normal 400 normal>,
#  <Font 'Letter Gothic Std' (LetterGothicStd-BoldSlanted.otf) italic normal bold normal>,
#  <Font 'Segoe Script' (segoesc.ttf) normal normal 400 normal>,
#  <Font 'SF Pro Display' (SF-Pro-Display-RegularItalic.otf) normal normal 400 normal>,
#  <Font 'Imprint MT Shadow' (IMPRISHA.TTF) normal normal 400 normal>,
#  <Font 'Century' (CENTURY.TTF) normal normal 400 normal>,
#  <Font 'Haan Cooljazz L' (HANCooljazzL.ttf) normal normal 400 normal>,
#  <Font 'EucrosiaUPC' (upceb.ttf) normal normal bold normal>,
#  <Font 'Bodoni Bk BT' (ENBODBKI.TTF) italic normal 400 normal>,
#  <Font 'HYmprL' (HYMPRL.TTF) normal normal 400 normal>,
#  <Font 'Bauhaus 93' (BAUHS93.TTF) normal normal 400 normal>,
#  <Font 'FZSong_Superfont' (FZSong_Super.TTF) normal normal 400 normal>,
#  <Font 'HYbdaM' (HYBDAM.TTF) normal normal 400 normal>,
#  <Font 'Miriam Fixed' (mriamc.ttf) normal normal 400 normal>,
#  <Font 'Segoe UI' (segoeuii.ttf) italic normal 400 normal>,
#  <Font 'Gabriola' (Gabriola.ttf) normal normal 400 normal>,
#  <Font 'Yj SOSEL SemiBold' (YSOS07.TTF) normal normal 400 normal>,
#  <Font 'Brush Script MT' (BRUSHSCI.TTF) italic normal 400 normal>,
#  <Font 'Castellar' (CASTELAR.TTF) normal normal 400 normal>,
#  <Font 'Bell MT' (BELLB.TTF) normal normal bold normal>,
#  <Font 'Giddyup Std' (GiddyupStd.otf) normal normal 400 normal>,
#  <Font 'MS Outlook' (OUTLOOK.TTF) normal normal 400 normal>,
#  <Font 'Constantia' (constanz.ttf) italic normal bold normal>,
#  <Font 'SF Pro Display' (SF-Pro-Display-ThinItalic.otf) normal normal 400 normal>,
#  <Font 'Yj GOTGAE Medium' (YGGE05.TTF) normal normal 400 normal>,
#  <Font 'Cooper Blk BT' (ENCOBKI.TTF) italic normal 400 normal>,
#  <Font 'Traditional Arabic' (tradbdo.ttf) normal normal bold normal>,
#  <Font 'SF Pro Display' (SF-Pro-Display-SemiboldItalic.otf) normal normal 400 normal>,
#  <Font 'Bodoni Bd BT' (ENBODBI.TTF) italic normal 400 normal>,
#  <Font 'Palatino Linotype' (palab.ttf) normal normal bold normal>,
#  <Font 'HYbdaL' (HYBDAL.TTF) normal normal 400 normal>,
#  <Font 'HYdnkM' (HYDNKM.TTF) normal normal 400 normal>,
#  <Font 'Tunga' (tunga.ttf) normal normal 400 normal>,
#  <Font 'OCR-A BT' (ENOCRA.TTF) normal normal 400 normal>,
#  <Font 'Eras Bold ITC' (ERASBD.TTF) normal normal bold normal>,
#  <Font 'Book Antiqua' (ANTQUAI.TTF) italic normal book normal>,
#  <Font 'SimSun-ExtB' (simsunb.ttf) normal normal 400 normal>,
#  <Font 'Bodoni MT' (BOD_B.TTF) normal normal bold normal>,
#  <Font 'Cordia New' (cordiai.ttf) italic normal 400 normal>,
#  <Font 'Minion Pro' (MinionPro-BoldCn.otf) normal normal bold condensed>,
#  <Font 'Segoe Script' (segoescb.ttf) normal normal bold normal>,
#  <Font 'ahn2006-L' (ahn_l.ttf) normal normal 400 normal>,
#  <Font 'Traditional Arabic' (trado.ttf) normal normal 400 normal>,
#  <Font 'Palatino Linotype' (pala.ttf) normal normal 400 normal>,
#  <Font 'Tekton Pro' (TektonPro-BoldExt.otf) normal normal bold normal>,
#  <Font 'Goudy Old Style' (GOUDOS.TTF) normal normal 400 normal>,
#  <Font 'HyhwpEQ' (HYHWPEQ.TTF) normal normal 400 normal>,
#  <Font 'Mesquite Std' (MesquiteStd.otf) normal normal medium normal>,
#  <Font 'Lucida Handwriting' (LHANDW.TTF) italic normal 400 normal>,
#  <Font 'HYGungSo-Bold' (H2GSRB.TTF) normal normal 400 normal>,
#  <Font 'Berlin Sans FB' (BRLNSB.TTF) normal normal bold normal>,
#  <Font 'Niagara Solid' (NIAGSOL.TTF) normal normal 400 normal>,
#  <Font 'HYgtrE' (HYGTRE.TTF) normal normal 400 normal>,
#  <Font 'SF Pro Display' (SF-Pro-Display-Ultralight.otf) normal normal 400 normal>,
#  <Font 'SF Pro Text' (SF-Pro-Text-RegularItalic.otf) normal normal 400 normal>,
#  <Font 'Arial monospaced for SAP' (arimon__.ttf) normal normal 400 normal>,
#  <Font 'Magneto' (MAGNETOB.TTF) normal normal bold normal>,
#  <Font 'Kristen ITC' (ITCKRIST.TTF) normal normal 400 normal>,
#  <Font 'Felix Titling' (FELIXTI.TTF) normal normal 400 normal>,
#  <Font 'Minion Pro' (MinionPro-BoldCnIt.otf) italic normal bold condensed>,
#  <Font 'Levenim MT' (lvnmbd.ttf) normal normal bold normal>,
#  <Font 'Franklin Gothic Book' (FRABK.TTF) normal normal book normal>,
#  <Font 'Kozuka Mincho Pro' (KozMinPro-Heavy.otf) normal normal 700 normal>,
#  <Font 'Juice ITC' (JUICE___.TTF) normal normal 400 normal>,
#  <Font 'Lucida Calligraphy' (LCALLIG.TTF) italic normal 400 normal>,
#  <Font 'Kozuka Mincho Pro' (KozMinPro-ExtraLight.otf) normal normal 400 normal>,
#  <Font 'Haan YGodic 230' (HANYGO230.ttf) normal normal 400 normal>,
#  <Font 'Microsoft Himalaya' (himalaya.ttf) normal normal 400 normal>,
#  <Font 'Haan YHead L' (HANYheadL.ttf) normal normal 400 normal>,
#  <Font 'Gisha' (gishabd.ttf) normal normal bold normal>,
#  <Font 'CordiaUPC' (cordiaui.ttf) italic normal 400 normal>,
#  <Font 'Century Schoolbook' (SCHLBKI.TTF) italic normal book normal>,
#  <Font 'Vrinda' (vrinda.ttf) normal normal 400 normal>,
#  <Font 'IrisUPC' (upcibi.ttf) italic normal bold normal>,
#  <Font 'HCR Batang Ext' (HANBatangExt.ttf) normal normal 400 normal>,
#  <Font 'Andalus' (andlso.ttf) normal normal 400 normal>,
#  <Font 'Malgun Gothic' (malgunbd.ttf) normal normal bold normal>,
#  <Font 'Tahoma' (tahoma.ttf) normal normal 400 normal>,
#  <Font 'Browallia New' (browai.ttf) italic normal 400 normal>,
#  <Font 'Arial Unicode MS' (ARIALUNI.TTF) normal normal 400 normal>,
#  <Font 'Adobe Caslon Pro' (ACaslonPro-BoldItalic.otf) italic normal bold normal>,
#  <Font 'SF Pro Text' (SF-Pro-Text-HeavyItalic.otf) normal normal 400 normal>,
#  <Font 'Franklin Gothic Medium' (framd.ttf) normal normal medium normal>,
#  <Font 'Lucida Console' (lucon.ttf) normal normal 400 normal>,
#  <Font 'Shruti' (shrutib.ttf) normal normal bold normal>,
#  <Font 'YDIYGO350' (윤고딕350.ttf) normal normal 400 normal>,
#  <Font 'Gisha' (gisha.ttf) normal normal 400 normal>,
#  <Font 'Haan YHead B' (HANYheadB.ttf) normal normal 400 normal>,
#  <Font 'Kozuka Mincho Pro' (KozMinPro-Regular.otf) normal normal 400 normal>,
#  <Font 'Vijaya' (vijaya.ttf) normal normal 400 normal>,
#  <Font 'Garamond' (GARAIT.TTF) italic normal 400 normal>,
#  <Font 'Shonar Bangla' (Shonarb.ttf) normal normal bold normal>,
#  <Font 'Gill Sans Ultra Bold Condensed' (GILLUBCD.TTF) normal normal bold condensed>,
#  <Font 'Adobe Garamond Pro' (AGaramondPro-Italic.otf) italic normal 400 normal>,
#  <Font 'Calibri' (calibrii.ttf) italic normal 400 normal>,
#  <Font 'ParkAvenue BT' (ENPKAV.TTF) italic normal 400 normal>,
#  <Font 'Century Gothic' (GOTHICB.TTF) normal normal bold normal>,
#  <Font 'Arial' (ARIALNI.TTF) italic normal 400 condensed>,
#  <Font 'HYdnkB' (HYDNKB.TTF) normal normal 400 normal>,
#  <Font 'Aparajita' (aparaj.ttf) normal normal 400 normal>,
#  <Font 'Kozuka Gothic Pro' (KozGoPro-Bold.otf) normal normal 700 normal>,
#  <Font 'Adobe Hebrew' (AdobeHebrew-Italic.otf) italic normal 400 normal>,
#  <Font 'Lucida Sans' (LSANSI.TTF) italic normal 400 normal>,
#  <Font 'Myriad Pro' (MyriadPro-SemiboldIt.otf) italic normal semibold normal>,
#  <Font 'OCR A Extended' (OCRAEXT.TTF) normal normal 400 normal>,
#  <Font 'Viner Hand ITC' (VINERITC.TTF) normal normal 400 normal>,
#  <Font 'Elephant' (ELEPHNTI.TTF) italic normal 400 normal>,
#  <Font 'AngsanaUPC' (angsaui.ttf) italic normal 400 normal>,
#  <Font 'Hobo BT' (ENHOBO.TTF) normal normal 400 normal>,
#  <Font 'Chaparral Pro' (ChaparralPro-BoldIt.otf) italic normal bold normal>,
#  <Font 'Kozuka Gothic Pro' (KozGoPro-Medium.otf) normal normal 400 normal>,
#  <Font 'SF Pro Display' (SF-Pro-Display-Thin.otf) normal normal 400 normal>,
#  <Font 'CentSchbook BT' (ENCSCHI.TTF) italic normal book normal>,
#  <Font 'Copperplate Gothic Bold' (COPRGTB.TTF) normal normal bold normal>,
#  <Font 'Haan YHead M' (HANYheadM.ttf) normal normal 400 normal>,
#  <Font 'Pristina' (PRISTINA.TTF) normal normal 400 normal>,
#  <Font 'Microsoft YaHei' (msyh.ttf) normal normal 400 normal>,
#  <Font 'Times New Roman' (times.ttf) normal normal roman normal>,
#  <Font 'Minion Pro' (MinionPro-MediumIt.otf) italic normal medium normal>,
#  <Font 'Edwardian Script ITC' (ITCEDSCR.TTF) normal normal 400 normal>,
#  <Font 'Yj INITIALPOSITIVE Medium' (YINP05.TTF) normal normal 400 normal>,
#  <Font 'Kokila' (kokilabi.ttf) italic normal bold normal>,
#  <Font 'Sylfaen' (sylfaen.ttf) normal normal 400 normal>,
#  <Font 'Cordia New' (cordiaz.ttf) italic normal bold normal>,
#  <Font 'Cambria' (cambriaz.ttf) italic normal bold normal>,
#  <Font 'Cooper Std' (CooperBlackStd-Italic.otf) italic normal black normal>,
#  <Font 'Microsoft Tai Le' (taile.ttf) normal normal 400 normal>,
#  <Font 'Colonna MT' (COLONNA.TTF) normal normal 400 normal>,
#  <Font 'Segoe Print' (segoeprb.ttf) normal normal bold normal>,
#  <Font 'Kozuka Mincho Pr6N' (KozMinPr6N-Regular.otf) normal normal 400 normal>,
#  <Font 'Candara' (Candaraz.ttf) italic normal bold normal>,
#  <Font 'Franklin Gothic Medium Cond' (FRAMDCN.TTF) normal normal medium condensed>,
#  <Font 'Adobe Song Std' (AdobeSongStd-Light.otf) normal normal 400 normal>,
#  <Font 'Aparajita' (aparajbi.ttf) italic normal bold normal>,
#  <Font 'Cordia New' (cordiab.ttf) normal normal bold normal>,
#  <Font 'SF Pro Text' (SF-Pro-Text-BoldItalic.otf) normal normal 400 normal>,
#  <Font 'Yj WADAG Medium' (YWDA05.TTF) normal normal 400 normal>,
#  <Font 'Microsoft New Tai Lue' (ntailu.ttf) normal normal 400 normal>,
#  <Font 'Gill Sans MT' (GILBI___.TTF) italic normal bold normal>,
#  <Font 'YJ BELLA Medium' (YBLA05.TTF) normal normal 400 normal>,
#  <Font 'DokChampa' (dokchamp.ttf) normal normal 400 normal>,
#  <Font 'Kozuka Gothic Pro' (KozGoPro-Heavy.otf) normal normal 700 normal>,
#  <Font 'Angsana New' (angsaz.ttf) italic normal bold normal>,
#  <Font 'Gill Sans MT' (GILB____.TTF) normal normal bold normal>,
#  <Font 'YDIYGO330' (윤고딕330.ttf) normal normal 400 normal>,
#  <Font 'Comic Sans MS' (comicbd.ttf) normal normal bold normal>,
#  <Font 'FangSong' (simfang.ttf) normal normal 400 normal>,
#  <Font 'GoudyOlSt BT' (ENGDOS.TTF) normal normal 400 normal>,
#  <Font 'Orator Std' (OratorStd-Slanted.otf) italic normal 400 normal>,
#  <Font 'Arial' (arialbd.ttf) normal normal bold normal>,
#  <Font 'CentSchbook BT' (ENCSCHBI.TTF) italic normal book normal>,
#  <Font 'Lucida Sans Typewriter' (LTYPEO.TTF) oblique normal 400 normal>,
#  <Font 'Yj DOOLGI Medium' (YDUG05.TTF) normal normal 400 normal>,
#  <Font 'FreesiaUPC' (upcfbi.ttf) italic normal bold normal>,
#  <Font 'Rod' (rod.ttf) normal normal 400 normal>,
#  <Font 'DFKai-SB' (kaiu.ttf) normal normal 400 normal>,
#  <Font 'AmeriGarmnd BT' (ENGARMBI.TTF) italic normal bold normal>,
#  <Font 'Microsoft New Tai Lue' (ntailub.ttf) normal normal bold normal>,
#  <Font 'HYnamL' (HYNAML.TTF) normal normal 400 normal>,
#  <Font 'Adobe Fangsong Std' (AdobeFangsongStd-Regular.otf) normal normal 400 normal>,
#  <Font 'Levenim MT' (lvnm.ttf) normal normal 400 normal>,
#  <Font 'SF Pro Display' (SF-Pro-Display-BoldItalic.otf) normal normal 400 normal>,
#  <Font 'Microsoft Yi Baiti' (msyi.ttf) normal normal 400 normal>,
#  <Font 'JasmineUPC' (upcjl.ttf) normal normal 400 normal>,
#  <Font 'Gloucester MT Extra Condensed' (GLECB.TTF) normal normal 400 condensed>,
#  <Font 'Latha' (latha.ttf) normal normal 400 normal>,
#  <Font 'Aharoni' (ahronbd.ttf) normal normal bold normal>,
#  <Font 'New Gulim' (NGULIM.TTF) normal normal 400 normal>,
#  <Font 'Vivaldi' (VIVALDII.TTF) italic normal 400 normal>,
#  <Font 'Rockwell Extra Bold' (ROCKEB.TTF) normal normal bold normal>,
#  <Font 'Bookshelf Symbol 7' (BSSYM7.TTF) normal normal book normal>,
#  <Font 'AmeriGarmnd BT' (ENGARMB.TTF) normal normal bold normal>,
#  <Font 'Swis721 BT' (ENSW721L.TTF) normal normal 400 normal>,
#  <Font 'Perpetua' (PER_____.TTF) normal normal 400 normal>,
#  <Font 'Yj MAEHWA  SemiBold' (YMAE07.TTF) normal normal 400 normal>,
#  <Font 'HYGothic-Medium' (H2GTRM.TTF) normal normal 400 normal>,
#  <Font 'Constantia' (constanb.ttf) normal normal bold normal>,
#  <Font 'Bookman Old Style' (BOOKOSI.TTF) italic normal book normal>,
#  <Font 'MSugiJeong' (MN.TTF) normal normal 400 normal>]

# %% [markdown]
# I found a Korean-supported ttf named 'Malgun Gothic' in the above list.

# %%
rc('font', family='Malgun Gothic')

# %%
station = ['사당', '신도림', '서울역', '동대문']
people = [300, 400, 300, 350]

# %%
positions = range(0, len(station))
plt.bar(positions, people)
plt.xticks(positions, station)
plt.xlabel('지하철역')
plt.ylabel('혼잡도')
plt.title('주요 지하철역의 혼잡도 비교')
plt.show()
